# %% [markdown]
# # <center> Processing Data in East Java</center>
#
# <center>By Teng Zhang</center>

# %% [markdown]
# ![image.png](attachment:image.png)
# Image from: the author

# %% [markdown]
# ---
# ### Authors:
# Teng Zhang, Department of Geography, Spatial Science and Environment, MSU

# %% [markdown]
# ---
# ### Abstract
# This program is intended to provide a OOG standard python file for pre-processing the data and regression of layers in my research.

# %% [markdown]
# ----
# # Statement of Need
#
# not applicable

# %% [markdown]
# ----
# # Installation instructions
# not applicable

# %% [markdown]
# ----
# # Unit Tests
# not applicable

# %% [markdown]
# ----
# # Example usage
# see readme.jupyter file

# %% [markdown]
# ---
# # Methodology
#
# not applicable

# %% [markdown]
# ---
# # Concluding Remarks
#
# too be continued

# %% [markdown]
# ----
# # Mentions
#
# not applicable

# %% [markdown]
# ----
# # References
#
# not applicable
